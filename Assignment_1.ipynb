# %% [markdown]
# <a href="https://colab.research.google.com/github/Kidar12/GDGoC_ML_Assignment1/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9d6ef97d-75ae-4a93-b401-3bb1292fc21f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9d6ef97d-75ae-4a93-b401-3bb1292fc21f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
data = pd.read_csv("/content/shoes_fact.csv")
print(data)
# Out:
#         Unnamed: 0      id  price  category    size  availability        date  \
# 0            63575  HP9426   60.0  sneakers      36             0  07/01/2025
# 1            63576  HP9426   60.0  sneakers  36 2/3             0  07/01/2025
# 2            63577  HP9426   60.0  sneakers  37 1/3             0  07/01/2025
# 3            63578  HP9426   60.0  sneakers      38             0  07/01/2025
# 4            63579  HP9426   60.0  sneakers  38 2/3             1  07/01/2025
# ...            ...     ...    ...       ...     ...           ...         ...
# 299151      847278  JI4476  160.0  sneakers  47 1/3             3  2025-01-16
# 299152      847279  JI4476  160.0  sneakers      48             0  2025-01-16
# 299153      847280  JI4476  160.0  sneakers  48 2/3             0  2025-01-16
# 299154      847281  JI4476  160.0  sneakers  49 1/3             2  2025-01-16
# 299155      847282  JI4476  160.0  sneakers  50 2/3             0  2025-01-16
#
#        country_code
# ...

# %%
import pandas as pd
data = pd.DataFrame({"id": ['JQ2552'], "price": [160.00]})
print(data)
# Out:
#        id  price
# 0  JQ2552  160.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("/content/shoes_fact.csv", parse_dates=['id'])

print(data.head(10))
# Out:
#    Unnamed: 0      id  price  category    size  availability        date  \
# 0       63575  HP9426   60.0  sneakers      36             0  07/01/2025
# 1       63576  HP9426   60.0  sneakers  36 2/3             0  07/01/2025
# 2       63577  HP9426   60.0  sneakers  37 1/3             0  07/01/2025
# 3       63578  HP9426   60.0  sneakers      38             0  07/01/2025
# 4       63579  HP9426   60.0  sneakers  38 2/3             1  07/01/2025
# 5       63580  HP9426   60.0  sneakers  39 1/3            15  07/01/2025
# 6       63581  HP9426   60.0  sneakers      40            15  07/01/2025
# 7       63582  HP9426   60.0  sneakers  40 2/3            15  07/01/2025
# 8       63583  HP9426   60.0  sneakers  41 1/3            15  07/01/2025
# 9       63584  HP9426   60.0  sneakers      42            15  07/01/2025
#
#   country_code
# 0           DE
# 1           DE
# 2           DE
# 3           DE
# 4           DE
# 5           DE
# 6           DE
# 7           DE
# 8           DE
# ...

# %%
print(data.shape)
# Out:
# (299156, 8)

# %%
print(data.info)
# Out:
# <bound method DataFrame.info of         Unnamed: 0      id  price  category    size  availability        date  \
# 0            63575  HP9426   60.0  sneakers      36             0  07/01/2025
# 1            63576  HP9426   60.0  sneakers  36 2/3             0  07/01/2025
# 2            63577  HP9426   60.0  sneakers  37 1/3             0  07/01/2025
# 3            63578  HP9426   60.0  sneakers      38             0  07/01/2025
# 4            63579  HP9426   60.0  sneakers  38 2/3             1  07/01/2025
# ...            ...     ...    ...       ...     ...           ...         ...
# 299151      847278  JI4476  160.0  sneakers  47 1/3             3  2025-01-16
# 299152      847279  JI4476  160.0  sneakers      48             0  2025-01-16
# 299153      847280  JI4476  160.0  sneakers  48 2/3             0  2025-01-16
# 299154      847281  JI4476  160.0  sneakers  49 1/3             2  2025-01-16
# 299155      847282  JI4476  160.0  sneakers  50 2/3             0  2025-01-16
#
# ...

# %%
plt.scatter(x=data['availability'], y=data['price'])

# %%
dataBar = data['category'].value_counts().plot(kind='bar', figsize=(14,6))

# %%
sns.histplot(data['price'], bins=10, kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.pairplot(data.iloc[:, 0:8])

# %% [markdown]
# **Insight**
# yang didapat dari dataset beserta visualisasinya adalah:
#
#
# *   **Scatter Plot:** Visualisasi ini menunjukkan ketersediaan barang(x) dan harga yang ditawarkan(y).
# *   **Bar Chart:** Visualisasi ini menunjukkan kategori sepatu manakah yang terbanyak dan hasilnya adalah *running-shoes*. Jadi dapat disimpulkan bahwa *running-shoes* begitu populer.
# *   **Histogram:** Visualisasi ini menunjukkan berbagai macam harga sepatu yang ada. Sebanyak 140.000 sepatu berada di *range* harga 50-100.
# *   **Pair Plot:** Visualisasi ini menunjukkan hubungan antara semua variable di dalam dataset.
